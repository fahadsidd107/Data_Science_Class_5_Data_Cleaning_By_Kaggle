# %%
import pandas as pd

# %%
data = pd.read_csv("netflix.csv",encoding='latin-1')
data.head(n=10)
# data.isnull().sum()
data.notnull().sum()
# Out:
# title                1000
# rating               1000
# ratingLevel           941
# ratingDescription    1000
# release year         1000
# user rating score     605
# user rating size     1000
# dtype: int64

# %%
data.tail(n=10)
# Out:
#                           title rating  \
# 990           My Animal Friends   TV-Y
# 991          Dawn of the Croods  TV-Y7
# 992  Alpha and Omega: Dino Digs   TV-G
# 993   Wiener Dog Internationals      G
# 994                    Pup Star      G
# 995                     The BFG     PG
# 996     The Secret Life of Pets     PG
# 997            Precious Puppies   TV-G
# 998                 Beary Tales   TV-G
# 999             Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 990                             Suitable for all ages.                 10
# 991             Suitable for children ages 7 and older                 41
# 992                             Suitable for all ages.                 35
# 993          General Audiences. Suitable for all ages.                 35
# 994          General Audiences. Suitable for all ages.                 35
# 995  for action/peril, some scary moments and brief...                 60
# ...

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.columns
# Out:
# Index(['title', 'rating', 'ratingLevel', 'ratingDescription', 'release year',
#        'user rating score', 'user rating size'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#Label based selection : LOC
#Index based selection : ILOC

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("netflix.csv",encoding='latin-1')
data.loc[(data.rating=="PG-13")]
# Out:
#                             title rating  \
# 0                    White Chicks  PG-13
# 250                  The Waterboy  PG-13
# 251    10 Things I Hate About You  PG-13
# 253  How to Lose a Guy in 10 Days  PG-13
# 254              The Benchwarmers  PG-13
# 255                       Step Up  PG-13
# 257                      Twilight  PG-13
# 273                  Mean Girls 2  PG-13
# 286                    Safe Haven  PG-13
# 300                  The Waterboy  PG-13
# 302           The Wedding Planner  PG-13
# 306                      Twilight  PG-13
# 322                  Mean Girls 2  PG-13
# 335        Trouble with the Curve  PG-13
# 372                 Unconditional  PG-13
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 250               language and some crude sexual humor                 80
# 251    adult content, adult language and mild violence                 80
# ...

# %%
data.loc[(data.rating=="TV-Y7") & (data["release year"]==2017)]
# Out:
#                                 title rating  \
# 630                Dawn of the Croods  TV-Y7
# 636    Home: Adventures with Tip & Oh  TV-Y7
# 693    Home: Adventures with Tip & Oh  TV-Y7
# 841  The Mr. Peabody and Sherman Show  TV-Y7
# 991                Dawn of the Croods  TV-Y7
#
#                                 ratingLevel  ratingDescription  release year  \
# 630  Suitable for children ages 7 and older                 41          2017
# 636  Suitable for children ages 7 and older                 41          2017
# 693  Suitable for children ages 7 and older                 41          2017
# 841  Suitable for children ages 7 and older                 41          2017
# 991  Suitable for children ages 7 and older                 41          2017
#
#      user rating score  user rating size
# 630               72.0                80
# 636                NaN                82
# 693                NaN                82
# 841                NaN                82
# ...

# %%
data.loc[(data.rating=="TV-14") & (data["user rating score"] >= 90) ]
# Out:
#                    title rating  \
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 5           Supernatural  TV-14
# 7    The Vampire Diaries  TV-14
# 9    Pretty Little Liars  TV-14
# ..                   ...    ...
# 472   Person of Interest  TV-14
# 474              Scandal  TV-14
# 476             Sherlock  TV-14
# 477      The Client List  TV-14
# 483        The Blacklist  TV-14
#
#                                            ratingLevel  ratingDescription  \
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 5    Parents strongly cautioned. May be unsuitable ...                 90
# 7    Parents strongly cautioned. May be unsuitable ...                 90
# 9    Parents strongly cautioned. May be unsuitable ...                 90
# ..                                                 ...                ...
# ...

# %%
data.loc[(data.rating=="TV-14"),["title","rating"]]
# Out:
#                    title rating
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 5           Supernatural  TV-14
# 7    The Vampire Diaries  TV-14
# 9    Pretty Little Liars  TV-14
# ..                   ...    ...
# 489             Rosewood  TV-14
# 491             Quantico  TV-14
# 492            Limitless  TV-14
# 495          No Tomorrow  TV-14
# 499            Greenleaf  TV-14
#
# [234 rows x 2 columns]

# %%
data.iloc[[10,15]]
# Out:
#                     title rating  \
# 10       Once Upon a Time  TV-PG
# 15  Lottie Dottie Chicken   TV-Y
#
#                                           ratingLevel  ratingDescription  \
# 10  Parental guidance suggested. May not be suitab...                 70
# 15                             Suitable for all ages.                 10
#
#     release year  user rating score  user rating size
# 10          2016               98.0                80
# 15          2009                NaN                82

# %%
data.iloc[[10,15,16],1:3]
# Out:
#    rating                                        ratingLevel
# 10  TV-PG  Parental guidance suggested. May not be suitab...
# 15   TV-Y                             Suitable for all ages.
# 16  TV-14  Parents strongly cautioned. May be unsuitable ...

# %%
data.iloc[0:3]
# Out:
#                  title rating  \
# 0         White Chicks  PG-13
# 1  Lucky Number Slevin      R
# 2       Grey's Anatomy  TV-14
#
#                                          ratingLevel  ratingDescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year  user rating score  user rating size
# 0          2004               82.0                80
# 1          2006                NaN                82
# 2          2016               98.0                80

# %%
data.iloc[2:6,2:5]
# Out:
#                                          ratingLevel  ratingDescription  \
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year
# 2          2016
# 3          2008
# 4          2014
# 5          2016

# %%
data.describe()
# Out:
#        ratingDescription  release year  user rating score  user rating size
# count         1000.00000   1000.000000         605.000000       1000.000000
# mean            67.36600   2010.335000          84.094215         80.783000
# std             30.78561      8.877927          12.344371          0.973066
# min             10.00000   1940.000000          55.000000         80.000000
# 25%             35.00000   2007.000000          75.000000         80.000000
# 50%             60.00000   2015.000000          88.000000         80.000000
# 75%             90.00000   2016.000000          95.000000         82.000000
# max            124.00000   2017.000000          99.000000         82.000000

# %% [markdown]
# # One hot encoding

# %%
data
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %%
data.isnull().sum()
# Out:
# title                  0
# rating                 0
# ratingLevel           59
# ratingDescription      0
# release year           0
# user rating score    395
# user rating size       0
# dtype: int64

# %%
round(data["user rating score"].mean())
# Out:
# 84

# %%
data.replace(to_replace=np.nan,value=round(data["user rating score"].mean()),inplace=True)

# %%
data
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %%
data.isnull().sum()
# Out:
# title                0
# rating               0
# ratingLevel          0
# ratingDescription    0
# release year         0
# user rating score    0
# user rating size     0
# dtype: int64
